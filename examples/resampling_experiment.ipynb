# %% [markdown]
# # 1 Introduction

# %% [markdown]
# This notebook demonstrates the functionality of hyperlearn module on the comparison of oversamplers on imbalanced datasets.

# %% [markdown]
# # 2 Imports

# %%
from hyperlearn.experiment import ResamplingExperiment
from hyperlearn.analysis import _extract_resamplers_classifiers
from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE, RandomOverSampler

# %% [markdown]
# # 3 Experiment

# %% [markdown]
# ##### 3.1 Configure experiment

# %%
bc = load_breast_cancer()
iris = load_iris()

X_bc, y_bc = bc.data, bc.target
X_iris, y_iris = iris.data, iris.target
y_iris[y_iris == 2] = 0

datasets = [
    ('bc', (X_bc, y_bc)),
    ('iris', (X_iris, y_iris))
]

smote_param_grid = [
    dict(kind=['borderline1', 'borderline2'], k_neighbors=[3, 6]),
    dict(k_neighbors=[2, 4])
]

dt_param_grid = [
    dict(max_depth=[2, 5]), 
    dict(criterion=['gini', 'entropy'], max_depth=[3, 6])
]

classifiers = [
    ('LR', LogisticRegression()), 
    ('DT', DecisionTreeClassifier(), dt_param_grid)
]

oversamplers = [
    ('No oversampling', None), 
    ('Random oversampler', RandomOverSampler()), 
    ('SMOTE', SMOTE(), smote_param_grid)
]

# %%
experiment = ResamplingExperiment(datasets, classifiers, oversamplers, n_jobs=-1)

# %% [markdown]
# #### 3.2 Run experiment

# %%
experiment.run()
# Out:
# 100% (60 of 60) |#########################| Elapsed Time: 0:00:11 ETA:  0:00:00

# %%
estimators = _extract_resamplers_classifiers(experiment)

# %%
estimators
# Out:
#     Classifier           Resampler  \
# 0           LR     No oversampling
# 1           DT     No oversampling
# 2           DT     No oversampling
# 3           DT     No oversampling
# 4           DT     No oversampling
# 5           DT     No oversampling
# 6           DT     No oversampling
# 7           LR  Random oversampler
# 8           DT  Random oversampler
# 9           DT  Random oversampler
# 10          DT  Random oversampler
# 11          DT  Random oversampler
# 12          DT  Random oversampler
# 13          DT  Random oversampler
# 14          LR               SMOTE
# 15          LR               SMOTE
# 16          LR               SMOTE
# 17          LR               SMOTE
# 18          LR               SMOTE
# 19          LR               SMOTE
# 20          DT               SMOTE
# 21          DT               SMOTE
# 22          DT               SMOTE
# 23          DT               SMOTE
# 24          DT               SMOTE
# 25          DT               SMOTE
# 26          DT               SMOTE
# 27          DT               SMOTE
# 28          DT               SMOTE
# 29          DT               SMOTE
# ..         ...                 ...
# 330         DT     No oversampling
# 331         LR  Random oversampler
# 332         DT  Random oversampler
# 333         DT  Random oversampler
# 334         DT  Random oversampler
# 335         DT  Random oversampler
# 336         DT  Random oversampler
# 337         DT  Random oversampler
# 338         LR               SMOTE
# 339         LR               SMOTE
# 340         LR               SMOTE
# 341         LR               SMOTE
# 342         LR               SMOTE
# 343         LR               SMOTE
# 344         DT               SMOTE
# 345         DT               SMOTE
# 346         DT               SMOTE
# 347         DT               SMOTE
# 348         DT               SMOTE
# 349         DT               SMOTE
# 350         DT               SMOTE
# 351         DT               SMOTE
# 352         DT               SMOTE
# 353         DT               SMOTE
# 354         DT               SMOTE
# 355         DT               SMOTE
# 356         DT               SMOTE
# 357         DT               SMOTE
# 358         DT               SMOTE
# 359         DT               SMOTE
#
#                                             Parameters
# 0                                                   {}
# 1                                 {'DT__max_depth': 2}
# 2                                 {'DT__max_depth': 5}
# 3        {'DT__criterion': 'gini', 'DT__max_depth': 3}
# 4        {'DT__criterion': 'gini', 'DT__max_depth': 6}
# 5     {'DT__criterion': 'entropy', 'DT__max_depth': 3}
# 6     {'DT__criterion': 'entropy', 'DT__max_depth': 6}
# 7                                                   {}
# 8                                 {'DT__max_depth': 2}
# 9                                 {'DT__max_depth': 5}
# 10       {'DT__criterion': 'gini', 'DT__max_depth': 3}
# 11       {'DT__criterion': 'gini', 'DT__max_depth': 6}
# 12    {'DT__criterion': 'entropy', 'DT__max_depth': 3}
# 13    {'DT__criterion': 'entropy', 'DT__max_depth': 6}
# 14   {'SMOTE__k_neighbors': 3, 'SMOTE__kind': 'bord...
# 15   {'SMOTE__k_neighbors': 3, 'SMOTE__kind': 'bord...
# 16   {'SMOTE__k_neighbors': 6, 'SMOTE__kind': 'bord...
# 17   {'SMOTE__k_neighbors': 6, 'SMOTE__kind': 'bord...
# 18                           {'SMOTE__k_neighbors': 2}
# 19                           {'SMOTE__k_neighbors': 4}
# 20   {'DT__max_depth': 2, 'SMOTE__k_neighbors': 3, ...
# 21   {'DT__max_depth': 2, 'SMOTE__k_neighbors': 3, ...
# 22   {'DT__max_depth': 2, 'SMOTE__k_neighbors': 6, ...
# 23   {'DT__max_depth': 2, 'SMOTE__k_neighbors': 6, ...
# 24   {'DT__max_depth': 5, 'SMOTE__k_neighbors': 3, ...
# 25   {'DT__max_depth': 5, 'SMOTE__k_neighbors': 3, ...
# 26   {'DT__max_depth': 5, 'SMOTE__k_neighbors': 6, ...
# 27   {'DT__max_depth': 5, 'SMOTE__k_neighbors': 6, ...
# 28   {'DT__criterion': 'gini', 'DT__max_depth': 3, ...
# 29   {'DT__criterion': 'gini', 'DT__max_depth': 3, ...
# ..                                                 ...
# 330   {'DT__criterion': 'entropy', 'DT__max_depth': 6}
# 331                                                 {}
# 332                               {'DT__max_depth': 2}
# 333                               {'DT__max_depth': 5}
# 334      {'DT__criterion': 'gini', 'DT__max_depth': 3}
# 335      {'DT__criterion': 'gini', 'DT__max_depth': 6}
# 336   {'DT__criterion': 'entropy', 'DT__max_depth': 3}
# 337   {'DT__criterion': 'entropy', 'DT__max_depth': 6}
# 338  {'SMOTE__k_neighbors': 3, 'SMOTE__kind': 'bord...
# 339  {'SMOTE__k_neighbors': 3, 'SMOTE__kind': 'bord...
# 340  {'SMOTE__k_neighbors': 6, 'SMOTE__kind': 'bord...
# 341  {'SMOTE__k_neighbors': 6, 'SMOTE__kind': 'bord...
# 342                          {'SMOTE__k_neighbors': 2}
# 343                          {'SMOTE__k_neighbors': 4}
# 344  {'DT__max_depth': 2, 'SMOTE__k_neighbors': 3, ...
# 345  {'DT__max_depth': 2, 'SMOTE__k_neighbors': 3, ...
# 346  {'DT__max_depth': 2, 'SMOTE__k_neighbors': 6, ...
# 347  {'DT__max_depth': 2, 'SMOTE__k_neighbors': 6, ...
# 348  {'DT__max_depth': 5, 'SMOTE__k_neighbors': 3, ...
# 349  {'DT__max_depth': 5, 'SMOTE__k_neighbors': 3, ...
# 350  {'DT__max_depth': 5, 'SMOTE__k_neighbors': 6, ...
# 351  {'DT__max_depth': 5, 'SMOTE__k_neighbors': 6, ...
# 352  {'DT__criterion': 'gini', 'DT__max_depth': 3, ...
# 353  {'DT__criterion': 'gini', 'DT__max_depth': 3, ...
# 354  {'DT__criterion': 'gini', 'DT__max_depth': 6, ...
# 355  {'DT__criterion': 'gini', 'DT__max_depth': 6, ...
# 356  {'DT__criterion': 'entropy', 'DT__max_depth': ...
# 357  {'DT__criterion': 'entropy', 'DT__max_depth': ...
# 358  {'DT__criterion': 'entropy', 'DT__max_depth': ...
# 359  {'DT__criterion': 'entropy', 'DT__max_depth': ...
#
# [360 rows x 3 columns]
