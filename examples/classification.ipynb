# %% [markdown]
# # 1 Introduction

# %% [markdown]
# This notebook demonstrates the functionality of hyperlearn module on multiple datasets and estiamtors.

# %% [markdown]
# # 2 Imports

# %%
from hyperlearn.experiment import ExtendedExperiment
from hyperlearn.analysis import extract_results
from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # 3 Experiment

# %% [markdown]
# ##### 3.1 Configure experiment

# %%
bc = load_breast_cancer()
iris = load_iris()

datasets = [
    ('bc', (bc.data, bc.target)),
    ('iris', (iris.data, iris.target))
]

smote_param_grid = [
    dict(kind=['borderline1', 'borderline2'], k_neighbors=[2, 3]), 
    dict(k_neighbors=[5, 6])
]

gbc_param_grid = [
    dict(n_estimators=[50, 100], max_depth = [3, 5]), 
    dict(max_depth = [5, 8])
]

smote_lr = [
    ('smote', SMOTE()),
    ('lr', LogisticRegression())
]

smote_gbc = [
    ('smote', SMOTE(), smote_param_grid), 
    ('gbc', GradientBoostingClassifier(), gbc_param_grid)
]

estimators = [smote_lr, smote_gbc]

# %%
experiment = ExtendedExperiment(datasets, estimators, scoring=['accuracy'], n_jobs=-1)

# %% [markdown]
# #### 3.2 Run experiment

# %%
experiment.run()
# Out:
# 100% (20 of 20) |#########################| Elapsed Time: 0:00:19 ETA:  0:00:00

# %%
extract_results(experiment)
# Out:
#    Experiment random seed Dataset  \
# 0               693381127      bc
# 0               693381127      bc
# 1               693381127      bc
# 2               693381127      bc
# 3               693381127      bc
# 4               693381127      bc
# 5               693381127      bc
# 6               693381127      bc
# 7               693381127      bc
# 8               693381127      bc
# 9               693381127      bc
# 10              693381127      bc
# 11              693381127      bc
# 12              693381127      bc
# 13              693381127      bc
# 14              693381127      bc
# 15              693381127      bc
# 16              693381127      bc
# 17              693381127      bc
# 18              693381127      bc
# 19              693381127      bc
# 0               693381127    iris
# 0               693381127    iris
# 1               693381127    iris
# 2               693381127    iris
# 3               693381127    iris
# 4               693381127    iris
# 5               693381127    iris
# 6               693381127    iris
# 7               693381127    iris
# ..                    ...     ...
# 11              247329429      bc
# 12              247329429      bc
# 13              247329429      bc
# 14              247329429      bc
# 15              247329429      bc
# 16              247329429      bc
# 17              247329429      bc
# 18              247329429      bc
# 19              247329429      bc
# 0               247329429    iris
# 0               247329429    iris
# 1               247329429    iris
# 2               247329429    iris
# 3               247329429    iris
# 4               247329429    iris
# 5               247329429    iris
# 6               247329429    iris
# 7               247329429    iris
# 8               247329429    iris
# 9               247329429    iris
# 10              247329429    iris
# 11              247329429    iris
# 12              247329429    iris
# 13              247329429    iris
# 14              247329429    iris
# 15              247329429    iris
# 16              247329429    iris
# 17              247329429    iris
# 18              247329429    iris
# 19              247329429    iris
#
#                                              Pipeline  \
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
# 16  Pipeline(memory=None,\n     steps=[('smote', S...
# 17  Pipeline(memory=None,\n     steps=[('smote', S...
# 18  Pipeline(memory=None,\n     steps=[('smote', S...
# 19  Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# ..                                                ...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
# 16  Pipeline(memory=None,\n     steps=[('smote', S...
# 17  Pipeline(memory=None,\n     steps=[('smote', S...
# 18  Pipeline(memory=None,\n     steps=[('smote', S...
# 19  Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
# 16  Pipeline(memory=None,\n     steps=[('smote', S...
# 17  Pipeline(memory=None,\n     steps=[('smote', S...
# 18  Pipeline(memory=None,\n     steps=[('smote', S...
# 19  Pipeline(memory=None,\n     steps=[('smote', S...
#
#                                            Parameters  accuracy
# 0                                                  {}  0.947276
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.950791
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.949033
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.949033
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.940246
# 4   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.961336
# 5   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.942004
# 6   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.956063
# 7   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.943761
# 8   {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.952548
# 9   {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.947276
# 10  {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.956063
# 11  {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.950791
# 12  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.961336
# 13  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.954306
# 14  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.954306
# 15  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.949033
# 16     {'gbc__max_depth': 5, 'smote__k_neighbors': 5}  0.957821
# 17     {'gbc__max_depth': 5, 'smote__k_neighbors': 6}  0.942004
# 18     {'gbc__max_depth': 8, 'smote__k_neighbors': 5}  0.942004
# 19     {'gbc__max_depth': 8, 'smote__k_neighbors': 6}  0.942004
# 0                                                  {}  0.960000
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.960000
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.960000
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.960000
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.960000
# 4   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 5   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.960000
# 6   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 7   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.960000
# ..                                                ...       ...
# 11  {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.952548
# 12  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.959578
# 13  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.950791
# 14  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.950791
# 15  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.964851
# 16     {'gbc__max_depth': 5, 'smote__k_neighbors': 5}  0.947276
# 17     {'gbc__max_depth': 5, 'smote__k_neighbors': 6}  0.949033
# 18     {'gbc__max_depth': 8, 'smote__k_neighbors': 5}  0.943761
# 19     {'gbc__max_depth': 8, 'smote__k_neighbors': 6}  0.938489
# 0                                                  {}  0.953333
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.953333
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.953333
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.953333
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.953333
# 4   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 5   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 6   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 7   {'gbc__max_depth': 3, 'gbc__n_estimators': 100...  0.953333
# 8   {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.953333
# 9   {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.953333
# 10  {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.953333
# 11  {'gbc__max_depth': 5, 'gbc__n_estimators': 50,...  0.953333
# 12  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.953333
# 13  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.953333
# 14  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.953333
# 15  {'gbc__max_depth': 5, 'gbc__n_estimators': 100...  0.953333
# 16     {'gbc__max_depth': 5, 'smote__k_neighbors': 5}  0.953333
# 17     {'gbc__max_depth': 5, 'smote__k_neighbors': 6}  0.953333
# 18     {'gbc__max_depth': 8, 'smote__k_neighbors': 5}  0.953333
# 19     {'gbc__max_depth': 8, 'smote__k_neighbors': 6}  0.953333
#
# [210 rows x 5 columns]
