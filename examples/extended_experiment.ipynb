# %% [markdown]
# # 1 Introduction

# %% [markdown]
# This notebook demonstrates the functionality of hyperlearn module on multiple datasets and estiamtors.

# %% [markdown]
# # 2 Imports

# %%
from hyperlearn.experiment import ExtendedExperiment
from hyperlearn.analysis import extract_results
from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # 3 Experiment

# %% [markdown]
# ##### 3.1 Configure experiment

# %%
bc = load_breast_cancer()
iris = load_iris()

datasets = [
    ('bc', (bc.data, bc.target)),
    ('iris', (iris.data, iris.target))
]

smote_param_grid = [ 
    dict(k_neighbors=[4, 6]),
    dict(kind=['borderline1', 'borderline2'], k_neighbors=[2, 3])
]

gbc_param_grid = [
    dict(n_estimators=[50, 80], max_depth = [3, 4]), 
    dict(max_depth = [6, 8])
]

smote_lr = [
    ('smote', SMOTE()),
    ('lr', LogisticRegression())
]

smote_gbc = [
    ('smote', SMOTE(), smote_param_grid), 
    ('gbc', GradientBoostingClassifier(), gbc_param_grid)
]

estimators = [smote_lr, smote_gbc]

# %%
experiment = ExtendedExperiment(datasets, estimators, scoring=['accuracy'], n_jobs=-1)

# %% [markdown]
# #### 3.2 Run experiment

# %%
experiment.run()
# Out:
# 100% (20 of 20) |#########################| Elapsed Time: 0:00:16 ETA:  0:00:00

# %%
extract_results(experiment)
# Out:
#    Experiment random seed Dataset  \
# 0               375681916      bc
# 0               375681916      bc
# 1               375681916      bc
# 2               375681916      bc
# 3               375681916      bc
# 4               375681916      bc
# 5               375681916      bc
# 6               375681916      bc
# 7               375681916      bc
# 8               375681916      bc
# 9               375681916      bc
# 10              375681916      bc
# 11              375681916      bc
# 12              375681916      bc
# 13              375681916      bc
# 14              375681916      bc
# 15              375681916      bc
# 0               375681916    iris
# 0               375681916    iris
# 1               375681916    iris
# 2               375681916    iris
# 3               375681916    iris
# 4               375681916    iris
# 5               375681916    iris
# 6               375681916    iris
# 7               375681916    iris
# 8               375681916    iris
# 9               375681916    iris
# 10              375681916    iris
# 11              375681916    iris
# ..                    ...     ...
# 3              1794613262      bc
# 4              1794613262      bc
# 5              1794613262      bc
# 6              1794613262      bc
# 7              1794613262      bc
# 8              1794613262      bc
# 9              1794613262      bc
# 10             1794613262      bc
# 11             1794613262      bc
# 12             1794613262      bc
# 13             1794613262      bc
# 14             1794613262      bc
# 15             1794613262      bc
# 0              1794613262    iris
# 0              1794613262    iris
# 1              1794613262    iris
# 2              1794613262    iris
# 3              1794613262    iris
# 4              1794613262    iris
# 5              1794613262    iris
# 6              1794613262    iris
# 7              1794613262    iris
# 8              1794613262    iris
# 9              1794613262    iris
# 10             1794613262    iris
# 11             1794613262    iris
# 12             1794613262    iris
# 13             1794613262    iris
# 14             1794613262    iris
# 15             1794613262    iris
#
#                                              Pipeline  \
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# ..                                                ...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 0   Pipeline(memory=None,\n     steps=[('smote', S...
# 1   Pipeline(memory=None,\n     steps=[('smote', S...
# 2   Pipeline(memory=None,\n     steps=[('smote', S...
# 3   Pipeline(memory=None,\n     steps=[('smote', S...
# 4   Pipeline(memory=None,\n     steps=[('smote', S...
# 5   Pipeline(memory=None,\n     steps=[('smote', S...
# 6   Pipeline(memory=None,\n     steps=[('smote', S...
# 7   Pipeline(memory=None,\n     steps=[('smote', S...
# 8   Pipeline(memory=None,\n     steps=[('smote', S...
# 9   Pipeline(memory=None,\n     steps=[('smote', S...
# 10  Pipeline(memory=None,\n     steps=[('smote', S...
# 11  Pipeline(memory=None,\n     steps=[('smote', S...
# 12  Pipeline(memory=None,\n     steps=[('smote', S...
# 13  Pipeline(memory=None,\n     steps=[('smote', S...
# 14  Pipeline(memory=None,\n     steps=[('smote', S...
# 15  Pipeline(memory=None,\n     steps=[('smote', S...
#
#                                            Parameters  accuracy
# 0                                                  {}  0.945518
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.950791
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.956063
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.952548
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.947276
# 4   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.943761
# 5   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.949033
# 6   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.945518
# 7   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.954306
# 8   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.927944
# 9   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.934974
# 10  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.938489
# 11  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.899824
# 12  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.940246
# 13  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.926186
# 14  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.945518
# 15  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.929701
# 0                                                  {}  0.960000
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.966667
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.966667
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.966667
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.966667
# 4   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.966667
# 5   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.966667
# 6   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.966667
# 7   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.966667
# 8   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.966667
# 9   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.966667
# 10  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.966667
# 11  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.966667
# ..                                                ...       ...
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.952548
# 4   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.947276
# 5   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.959578
# 6   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.950791
# 7   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.956063
# 8   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.949033
# 9   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.927944
# 10  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.924429
# 11  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.933216
# 12  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.956063
# 13  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.934974
# 14  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.929701
# 15  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.924429
# 0                                                  {}  0.946667
# 0   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.933333
# 1   {'gbc__max_depth': 3, 'gbc__n_estimators': 50,...  0.933333
# 2   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.933333
# 3   {'gbc__max_depth': 3, 'gbc__n_estimators': 80,...  0.933333
# 4   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.940000
# 5   {'gbc__max_depth': 4, 'gbc__n_estimators': 50,...  0.933333
# 6   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.940000
# 7   {'gbc__max_depth': 4, 'gbc__n_estimators': 80,...  0.940000
# 8   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.940000
# 9   {'gbc__max_depth': 6, 'smote__k_neighbors': 2,...  0.940000
# 10  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.940000
# 11  {'gbc__max_depth': 6, 'smote__k_neighbors': 3,...  0.940000
# 12  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.940000
# 13  {'gbc__max_depth': 8, 'smote__k_neighbors': 2,...  0.940000
# 14  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.940000
# 15  {'gbc__max_depth': 8, 'smote__k_neighbors': 3,...  0.940000
#
# [170 rows x 5 columns]
